# %% [markdown]
# <a href="https://colab.research.google.com/github/mdaugherity/Numerical2026/blob/main/linear/HW1_Linear.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# **PHYS 351 - Fall 2026**
# # HW1 - Linear Systems
#
# Complete these exercises.  Submit your work by sharing your Colab Notebook with me

# %%
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# # Problem 0 - Statics
#
# ![hw1 truss.png](data:image/png;base64,...)

# %% [markdown]
# Sorry for the low resolution  :(

# %% [markdown]
# # Problem 1 - Circuit

# %% [markdown]
# ![hw1 circuit.png](data:image/png;base64,...)

# %% [markdown]
# Here's how you could format this in $\LaTeX$
#
# $ \begin{bmatrix} (50+R) & -R & -30 \\ -R & (65+R) & -15 \\ -30 & -15 & 45 \end{bmatrix}
# \begin{bmatrix} i_1 \\ i_2 \\ i_3 \end{bmatrix}
# = \begin{bmatrix} 0 \\ 0 \\ 120 \end{bmatrix}
#  $

# %% [markdown]
# # Problem 3
# Complete the function defined below. Requirements:
# *  Take the typical coefficent matrices A and b as input
# *  Print the solution
# *  Make a lovely plot showing both lines and the solution (if it exists)
# *  You must check the dimensions and print an error message if A isn't 2x2 or b isn't 2x1
# *  Print the determinant and condition of A
# *  Print a message that correctly states if there are no solutions, one solution, or infinite solutions
#
#
# Prove to me that your function works by showing test cases

# %%
def LinearSystemSolver(A, b):
  """Solves and plots a 2D linear system"""

return
